# %% [markdown]
# <a href="https://colab.research.google.com/github/kshitijzope/test/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip -q install langchain
# !pip -q install bitsandbytes accelerate transformers
# !pip -q install dataset loralib sentencepiece
# !pip -q install pypdf
# !pip -q install sentence_transformers
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 27.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.4/49.4 kB 6.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.6/92.6 MB 1.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 244.2/244.2 kB 25.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.4/7.4 MB 113.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 29.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 109.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 82.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 17.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 39.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 225.4/225.4 kB 19.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.7/78.7 kB 8.4 MB/s eta 0:00:00
# ...

# %%
# !pip -q install unstructured
# !pip -q install tokenizers
# !pip -q install faiss-cpu
# !pip install pinecone-client
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 19.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 358.9/358.9 kB 36.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.6/17.6 MB 61.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 179.1/179.1 kB 2.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.0/60.0 kB 7.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 300.4/300.4 kB 29.6 MB/s eta 0:00:00
# ...

# %%
from langchain.document_loaders import UnstructuredURLLoader

# %%
from langchain.text_splitter import CharacterTextSplitter

# %%
from langchain.embeddings import OpenAIEmbeddings

# %%
from langchain.chat_models import ChatOpenAI

# %%
from langchain.vectorstores import FAISS

# %%
from langchain.vectorstores import Pinecone
from transformers import AutoTokenizer, AutoModelForCausalLM

# %%
import pinecone

# %%
from langchain.chains import RetrievalQAWithSourcesChain

# %%
from langchain.embeddings import HuggingFaceEmbeddings

# %%
from transformers import pipeline

# %%
from langchain import HuggingFacePipeline

# %%
from huggingface_hub import notebook_login

# %%
import textwrap

# %%
import sys

# %%
import os

# %%
import torch

# %%
import nltk
nltk.download('punkt')
nltk.download('averaged_preceptron_trigger')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Error loading averaged_preceptron_trigger: Package
# [nltk_data]     'averaged_preceptron_trigger' not found in index
# False

# %%
embeddings=HuggingFaceEmbeddings(model_name='sentence-transformers/all-MiniLM-L6-v2')
embeddings=HuggingFaceEmbeddings()
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_errors.py in hf_raise_for_status(response, endpoint_name)
#     260     try:
# --> 261         response.raise_for_status()
#     262     except HTTPError as e:
#
# /usr/local/lib/python3.10/dist-packages/requests/models.py in raise_for_status(self)
#    1020         if http_error_msg:
# -> 1021             raise HTTPError(http_error_msg, response=self)
#    1022
#
# HTTPError: 504 Server Error: Gateway Time-out for url: https://huggingface.co/api/models/sentence-transformers/all-MiniLM-L6-v2
#
# The above exception was the direct cause of the following exception:
#
# HfHubHTTPError                            Traceback (most recent call last)
# <ipython-input-21-2043ca6a5f6d> in <cell line: 1>()
# ...

# %%
query_result = embeddings.embed_query("Hello world")
len(query_result)

# %%
URLs=[
    'https://blog.gopenai.com/paper-review-llama-2-open-foundation-and-fine-tuned-chat-models-23e539522acb',
    'https://www.mosaicml.com/blog/mpt-7b',
    'https://stability.ai/blog/stability-ai-launches-the-first-of-its-stablelm-suite-of-language-models',
    'https://lmsys.org/blog/2023-03-30-vicuna/'

]

# %%
loaders=UnstructuredURLLoader(urls=URLs)
data=loaders.load()

# %%
text_splitter=CharacterTextSplitter(separator='\n',
                                    chunk_size=1000,
                                    chunk_overlap=200)

# %%
text_chunks=text_splitter.split_documents(data)

# %%
vectorstore=FAISS.from_documents(text_chunks, embeddings)

# %%
notebook_login()

# %%
tokenizer = AutoTokenizer.from_pretrained("meta-llama/Llama-2-7b-chat-hf",
                                          use_auth_token=True,)


model = AutoModelForCausalLM.from_pretrained("meta-llama/Llama-2-7b-chat-hf",
                                             device_map='auto',
                                             torch_dtype=torch.float16,
                                             use_auth_token=True,
                                              load_in_8bit=True,
                                              #load_in_4bit=True
                                             )
# Out:
# ...
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1714: FutureWarning: The `use_auth_token` argument is deprecated and will be removed in v5 of Transformers.
#   warnings.warn(
# ...
# /usr/local/lib/python3.10/dist-packages/transformers/modeling_utils.py:2193: FutureWarning: The `use_auth_token` argument is deprecated and will be removed in v5 of Transformers.
#   warnings.warn(
# ...
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# ...

# %%
pipe = pipeline("text-generation",
                model=model,
                tokenizer= tokenizer,
                torch_dtype=torch.bfloat16,
                device_map="auto",
                max_new_tokens = 512,
                do_sample=True,
                top_k=30,
                num_return_sequences=1,
                eos_token_id=tokenizer.eos_token_id
                )
# Out:
# Xformers is not installed correctly. If you want to use memory_efficient_attention to accelerate training use the following command to install Xformers
# pip install xformers.

# %%
llm=HuggingFacePipeline(pipeline=pipe, model_kwargs={'temperature':0})

# %%
llm.predict("Please provide a concise summary of the Book Alchemist")
# Out:
# ' by Paulo Coelho. Here is a brief summary of the book In The Alchemist, Paulo Coelho tells the story of a young shepherd named Santiago, who embarks on a quest to fulfill his personal legend and find his treasure.\n1. Introduction 2. Conclusion 3. Plot Summary 4. Characters 5. Themes 6. Symbols 7. Style and Language 8. Historical Context 9. Cultural Significance 10. Critical Reception and Awards.\nSantiago experiences a recurring dream of finding treasure at the pyramids in Egypt, and he sets off to pursue his personal legend. He encounters various people and experiences throughout his journey, including a gypsy woman, Fatima, who interprets his dream and a crystal merchant, Melchizedek, who provides spiritual guidance and teaches him about the importance of listening to his heart.\nSantiago learns valuable lessons about the power of belief, the importance of following his dreams, and the interconnectedness of all things. He also learns that his personal legend is not just about fin
# ...

# %%
chain = RetrievalQAWithSourcesChain.from_llm(llm=llm, retriever=vectorstore.as_retriever())

# %%
result=chain({"question": "How good is Vicuna?"}, return_only_outputs=True)
# Out:
# ...
# Token indices sequence length is longer than the specified maximum sequence length for this model (1755 > 1024). Running this sequence through the model will result in indexing errors

# %%
result['answer']
# Out:
# " Vicuna is a highly capable language model, with a score of 92% of ChatGPT's total score and a 90% capability of Bard/ChatGPT.\n"

# %%
wrapped_text = textwrap.fill(result['answer'], width=500)

# %%
wrapped_text
# Out:
# " Vicuna is a highly capable language model, with a score of 92% of ChatGPT's total score and a 90% capability of Bard/ChatGPT."

# %%
result=chain({"question": "Can you please share some details about MPT-7b Model"}, return_only_outputs=True)
# Out:
# Token indices sequence length is longer than the specified maximum sequence length for this model (1832 > 1024). Running this sequence through the model will result in indexing errors
# /usr/local/lib/python3.10/dist-packages/transformers/pipelines/base.py:1083: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(

# %%
result['answer']
# Out:
# ' MPT-7B is a base model for Natural Language Processing (NLP) tasks, trained on a dataset of 440GB on A100-40GB GPUs, and cost nearly $200,000.\n'

# %%
wrapped_text = textwrap.fill(result['answer'], width=100)

# %%
wrapped_text
# Out:
# ' MPT-7B is a base model for Natural Language Processing (NLP) tasks, trained on a dataset of 440GB\non A100-40GB GPUs, and cost nearly $200,000.'

# %%
while True:
  query=input(f"Prompt: ")
  if query == 'exit':
    print('Exiting')
    sys.exit()
  if query =='':
    continue
  result=chain({'question':query})
  print(f"Answer: " +result["answer"])
